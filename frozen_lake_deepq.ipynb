# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import random
from collections import deque
from time import sleep
from ipythonblocks import BlockGrid
from IPython.display import clear_output

# Define the Q-Network
class DQN(nn.Module):
    def __init__(self):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(2, 128)  # Input is the (x, y) position of the agent
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, 4)  # Output is the Q-value for each action (up, down, left, right)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

# Agent class for DQN
class DQNAgent:
    def __init__(self):
        self.model = DQN()
        self.target_model = DQN()  # Target network for stable training
        self.target_model.load_state_dict(self.model.state_dict())
        self.optimizer = optim.Adam(self.model.parameters(), lr=0.001)
        self.loss_fn = nn.MSELoss()
        self.memory = deque(maxlen=10000)
        self.gamma = 0.99  # Discount factor
        self.epsilon = 1.0  # Exploration rate
        self.epsilon_decay = 0.995
        self.epsilon_min = 0.01
        self.batch_size = 64
        self.update_target_every = 10
        self.steps = 0

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() < self.epsilon:
            return random.choice([0, 1, 2, 3])  # Random action (explore)
        state = torch.FloatTensor(state).unsqueeze(0)
        q_values = self.model(state)
        return torch.argmax(q_values).item()  # Choose action with highest Q-value (exploit)

    def replay(self):
        if len(self.memory) < self.batch_size:
            return

        batch = random.sample(self.memory, self.batch_size)
        for state, action, reward, next_state, done in batch:
            state = torch.FloatTensor(state).unsqueeze(0)
            next_state = torch.FloatTensor(next_state).unsqueeze(0)
            target = self.model(state)
            with torch.no_grad():
                target_next = self.target_model(next_state)

            target[0][action] = reward + (self.gamma * torch.max(target_next)) * (1 - done)

            self.optimizer.zero_grad()
            loss = self.loss_fn(self.model(state), target)
            loss.backward()
            self.optimizer.step()

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

    def update_target_network(self):
        self.target_model.load_state_dict(self.model.state_dict())

# Update FLModel to return rewards
class FLModel:
    def __init__(self):
        self.decision_dict = {"up": np.array((0, -1)), "down": np.array((0, 1)), "left": np.array((-1, 0)), "right": np.array((1, 0))}

    def exog_info(self, state, decision):
        if random.random() < 0.3:
            return "slip"
        else:
            return "move"

    def transition_function(self, state, decision, exog_info):
        if exog_info != "slip":
            new_position = state + self.decision_dict[decision]
            if not ((new_position == (-1, -1)).any() or (new_position == (4, 4)).any()):
                return new_position
            
        possible_positions = []
        for key in self.decision_dict.keys():
            new_position = state + self.decision_dict[key]
            if not ((new_position == (-1, -1)).any() or (new_position == (4, 4)).any()):
                possible_positions.append(new_position)

        return random.choice(possible_positions)

    def is_complete(self, state):
        return (state == (3, 3)).all()

    def get_reward(self, state):
        if self.is_complete(state):
            return 10  # Goal reached
        return -1  # Small penalty for each move
    
    def draw_state(self, state):
        agent_colour = (0, 0, 255)
        goal_colour = (210, 30, 30)
        clean_colour = (255, 255, 255)
        
        # Create the grid with the given width and height
        grid = BlockGrid(4, 4, fill=clean_colour)
        
        goal_position = (3, 3)
        agent_position = state
        
        # Set the agent's position with its color
        grid[goal_position[1], goal_position[0]] = goal_colour
        grid[int(agent_position[1]), int(agent_position[0])] = agent_colour
        
        clear_output(wait=True)
        # Show the grid
        grid.show()
        
        # Add a small delay for visualization purposes
        sleep(0.5)

    # Method to run the trained agent in the environment and visualize
    def run_trained_agent(self, S0, agent, n_iterations: int = 100):
        current_state = S0
        for n in range(n_iterations):
            self.draw_state(current_state)  # Visualize the state
            action = agent.act(current_state)  # Let the trained agent decide an action
            action_name = ["up", "down", "left", "right"][action]  # Convert action index to action name
            exog = self.exog_info(current_state, action_name)  # Get external environment info
            current_state = self.transition_function(current_state, action_name, exog)  # Transition to next state
            
            if self.is_complete(current_state):  # Check if goal is reached
                self.draw_state(current_state)  # Final state visualization
                print(f"Goal reached in {n+1} steps!")
                break
        else:
            print("Agent did not reach the goal.")
# Out:
# Episode 1: Total Reward = -43
# Episode 2: Total Reward = -61
# Episode 3: Total Reward = -71
# Episode 4: Total Reward = -3
# Episode 5: Total Reward = -1
# Episode 6: Total Reward = -23
# Episode 7: Total Reward = -91
# Episode 8: Total Reward = -89
# Episode 9: Total Reward = -7
# Episode 10: Total Reward = -11
# Episode 11: Total Reward = -13
# Episode 12: Total Reward = -29
# Episode 13: Total Reward = -3
# Episode 14: Total Reward = -67
# Episode 15: Total Reward = -19
# Episode 16: Total Reward = -67
# Episode 17: Total Reward = -13
# Episode 18: Total Reward = -61
# Episode 19: Total Reward = -3
# Episode 20: Total Reward = 3
# Episode 21: Total Reward = -41
# Episode 22: Total Reward = -31
# Episode 23: Total Reward = -9
# Episode 24: Total Reward = -5
# Episode 25: Total Reward = -1
# Episode 26: Total Reward = -19
# Episode 27: Total Reward = -13
# Episode 28: Total Reward = -3
# Episode 29: Total Reward = -19
# Episode 30: Total Reward = -53
# Episode 31: Total Reward = -7
# Episode 32: Total Reward = -73
# Episode 33: Total Reward = -59
# Episode 34: Total Reward = -45
# Episode 35: Total Reward = -37
# Episode 36: Total Reward = -23
# Episode 37: Total Reward = -5
# Episode 38: Total Reward = -7
# Episode 39: Total Reward = -11
# Episode 40: Total Reward = -139
# Episode 41: Total Reward = -13
# Episode 42: Total Reward = -3
# Episode 43: Total Reward = 3
# Episode 44: Total Reward = -19
# Episode 45: Total Reward = -3
# Episode 46: Total Reward = -13
# Episode 47: Total Reward = -23
# Episode 48: Total Reward = 3
# Episode 49: Total Reward = 1
# Episode 50: Total Reward = -19
# Episode 51: Total Reward = -45
# Episode 52: Total Reward = -7
# Episode 53: Total Reward = -21
# Episode 54: Total Reward = -9
# Episode 55: Total Reward = -17
# Episode 56: Total Reward = -17
# Episode 57: Total Reward = -7
# Episode 58: Total Reward = -43
# Episode 59: Total Reward = -7
# Episode 60: Total Reward = -27
# Episode 61: Total Reward = 1
# Episode 62: Total Reward = -3
# Episode 63: Total Reward = -35
# Episode 64: Total Reward = -5
# Episode 65: Total Reward = -81
# Episode 66: Total Reward = 3
# Episode 67: Total Reward = -17
# Episode 68: Total Reward = -3
# Episode 69: Total Reward = -3
# Episode 70: Total Reward = -23
# Episode 71: Total Reward = 1
# Episode 72: Total Reward = -1
# Episode 73: Total Reward = -47
# Episode 74: Total Reward = 1
# Episode 75: Total Reward = -3
# Episode 76: Total Reward = -7
# Episode 77: Total Reward = -27
# Episode 78: Total Reward = -9
# Episode 79: Total Reward = 1
# Episode 80: Total Reward = -3
# Episode 81: Total Reward = -47
# Episode 82: Total Reward = -41
# Episode 83: Total Reward = -3
# Episode 84: Total Reward = -3
# Episode 85: Total Reward = -5
# Episode 86: Total Reward = -5
# Episode 87: Total Reward = 3
# Episode 88: Total Reward = 3
# Episode 89: Total Reward = -3
# Episode 90: Total Reward = -25
# Episode 91: Total Reward = 3
# Episode 92: Total Reward = 1
# Episode 93: Total Reward = -67
# Episode 94: Total Reward = 3
# Episode 95: Total Reward = -13
# Episode 96: Total Reward = -9
# Episode 97: Total Reward = -3
# Episode 98: Total Reward = -37
# Episode 99: Total Reward = -21
# Episode 100: Total Reward = -19
# Episode 101: Total Reward = -11
# Episode 102: Total Reward = 5
# Episode 103: Total Reward = -33
# Episode 104: Total Reward = 1
# Episode 105: Total Reward = -17
# Episode 106: Total Reward = 5
# Episode 107: Total Reward = -5
# Episode 108: Total Reward = -23
# Episode 109: Total Reward = -19
# Episode 110: Total Reward = -3
# Episode 111: Total Reward = -9
# Episode 112: Total Reward = -3
# Episode 113: Total Reward = 5
# Episode 114: Total Reward = -3
# Episode 115: Total Reward = -31
# Episode 116: Total Reward = 3
# Episode 117: Total Reward = -5
# Episode 118: Total Reward = -1
# Episode 119: Total Reward = -13
# Episode 120: Total Reward = 1
# Episode 121: Total Reward = -5
# Episode 122: Total Reward = -17
# Episode 123: Total Reward = -11
# Episode 124: Total Reward = -5
# Episode 125: Total Reward = -19
# Episode 126: Total Reward = 3
# Episode 127: Total Reward = -1
# Episode 128: Total Reward = 3
# Episode 129: Total Reward = -7
# Episode 130: Total Reward = -3
# Episode 131: Total Reward = -11
# Episode 132: Total Reward = -11
# Episode 133: Total Reward = -13
# Episode 134: Total Reward = -19
# Episode 135: Total Reward = 5
# Episode 136: Total Reward = -3
# Episode 137: Total Reward = -1
# Episode 138: Total Reward = -9
# Episode 139: Total Reward = -13
# Episode 140: Total Reward = 1
# Episode 141: Total Reward = -19
# Episode 142: Total Reward = -5
# Episode 143: Total Reward = 3
# Episode 144: Total Reward = -13
# Episode 145: Total Reward = 3
# Episode 146: Total Reward = -3
# Episode 147: Total Reward = -9
# Episode 148: Total Reward = -1
# Episode 149: Total Reward = 1
# Episode 150: Total Reward = 3
# Episode 151: Total Reward = -3
# Episode 152: Total Reward = -3
# Episode 153: Total Reward = -11
# Episode 154: Total Reward = -1
# Episode 155: Total Reward = -1
# Episode 156: Total Reward = -5
# Episode 157: Total Reward = -23
# Episode 158: Total Reward = 3
# Episode 159: Total Reward = 3
# Episode 160: Total Reward = -9
# Episode 161: Total Reward = 3
# Episode 162: Total Reward = -7
# Episode 163: Total Reward = -17
# Episode 164: Total Reward = -7
# Episode 165: Total Reward = -5
# Episode 166: Total Reward = -9
# Episode 167: Total Reward = -9
# Episode 168: Total Reward = 3
# Episode 169: Total Reward = 5
# Episode 170: Total Reward = -15
# Episode 171: Total Reward = 1
# Episode 172: Total Reward = 3
# Episode 173: Total Reward = -5
# Episode 174: Total Reward = -3
# Episode 175: Total Reward = -17
# Episode 176: Total Reward = -17
# Episode 177: Total Reward = 3
# Episode 178: Total Reward = -17
# Episode 179: Total Reward = -21
# Episode 180: Total Reward = -1
# Episode 181: Total Reward = -1
# Episode 182: Total Reward = 3
# Episode 183: Total Reward = -3
# Episode 184: Total Reward = -7
# Episode 185: Total Reward = 1
# Episode 186: Total Reward = -3
# Episode 187: Total Reward = -15
# Episode 188: Total Reward = 3
# Episode 189: Total Reward = 3
# Episode 190: Total Reward = -23
# Episode 191: Total Reward = 5
# Episode 192: Total Reward = -3
# Episode 193: Total Reward = -5
# Episode 194: Total Reward = -17
# Episode 195: Total Reward = -17
# Episode 196: Total Reward = -7
# Episode 197: Total Reward = 3
# Episode 198: Total Reward = 5
# Episode 199: Total Reward = 3
# Episode 200: Total Reward = 5
# Episode 201: Total Reward = -1
# Episode 202: Total Reward = -5
# Episode 203: Total Reward = 1
# Episode 204: Total Reward = -1
# Episode 205: Total Reward = -13
# Episode 206: Total Reward = -15
# Episode 207: Total Reward = -9
# Episode 208: Total Reward = 3
# Episode 209: Total Reward = 1
# Episode 210: Total Reward = 5
# Episode 211: Total Reward = -47
# Episode 212: Total Reward = -1
# Episode 213: Total Reward = 3
# Episode 214: Total Reward = 1
# Episode 215: Total Reward = -9
# Episode 216: Total Reward = 5
# Episode 217: Total Reward = -7
# Episode 218: Total Reward = 3
# Episode 219: Total Reward = -11
# Episode 220: Total Reward = -5
# Episode 221: Total Reward = -5
# Episode 222: Total Reward = -31
# Episode 223: Total Reward = -5
# Episode 224: Total Reward = -7
# Episode 225: Total Reward = 5
# Episode 226: Total Reward = -1
# Episode 227: Total Reward = 3
# Episode 228: Total Reward = 1
# Episode 229: Total Reward = -7
# Episode 230: Total Reward = -3
# Episode 231: Total Reward = -5
# Episode 232: Total Reward = 5
# Episode 233: Total Reward = 5
# Episode 234: Total Reward = 5
# Episode 235: Total Reward = 3
# Episode 236: Total Reward = 1
# Episode 237: Total Reward = 1
# Episode 238: Total Reward = 3
# Episode 239: Total Reward = -11
# Episode 240: Total Reward = -1
# Episode 241: Total Reward = -1
# Episode 242: Total Reward = -5
# Episode 243: Total Reward = -5
# Episode 244: Total Reward = 5
# Episode 245: Total Reward = -3
# Episode 246: Total Reward = -3
# Episode 247: Total Reward = -15
# Episode 248: Total Reward = 5
# Episode 249: Total Reward = 1
# Episode 250: Total Reward = 5
# Episode 251: Total Reward = 1
# Episode 252: Total Reward = 5
# Episode 253: Total Reward = -31
# Episode 254: Total Reward = 5
# Episode 255: Total Reward = -31
# Episode 256: Total Reward = 1
# Episode 257: Total Reward = 5
# Episode 258: Total Reward = -7
# Episode 259: Total Reward = -25
# Episode 260: Total Reward = -7
# Episode 261: Total Reward = -1
# Episode 262: Total Reward = 3
# Episode 263: Total Reward = -11
# Episode 264: Total Reward = 5
# Episode 265: Total Reward = 3
# Episode 266: Total Reward = 1
# Episode 267: Total Reward = 3
# Episode 268: Total Reward = 5
# Episode 269: Total Reward = -5
# Episode 270: Total Reward = 1
# Episode 271: Total Reward = 5
# Episode 272: Total Reward = 5
# Episode 273: Total Reward = 3
# Episode 274: Total Reward = -1
# Episode 275: Total Reward = -5
# Episode 276: Total Reward = -7
# Episode 277: Total Reward = -5
# Episode 278: Total Reward = -7
# Episode 279: Total Reward = -1
# Episode 280: Total Reward = -11
# Episode 281: Total Reward = -1
# Episode 282: Total Reward = 5
# Episode 283: Total Reward = 3
# Episode 284: Total Reward = -9
# Episode 285: Total Reward = -17
# Episode 286: Total Reward = 3
# Episode 287: Total Reward = -1
# Episode 288: Total Reward = -1
# Episode 289: Total Reward = 5
# Episode 290: Total Reward = -1
# Episode 291: Total Reward = -17
# Episode 292: Total Reward = 1
# Episode 293: Total Reward = -1
# Episode 294: Total Reward = -5
# Episode 295: Total Reward = -1
# Episode 296: Total Reward = -45
# Episode 297: Total Reward = 1
# Episode 298: Total Reward = 1
# Episode 299: Total Reward = 5
# Episode 300: Total Reward = 3
# Episode 301: Total Reward = -1
# Episode 302: Total Reward = -7
# Episode 303: Total Reward = 1
# Episode 304: Total Reward = -7
# Episode 305: Total Reward = -11
# Episode 306: Total Reward = -1
# Episode 307: Total Reward = -1
# Episode 308: Total Reward = -15
# Episode 309: Total Reward = 1
# Episode 310: Total Reward = -13
# Episode 311: Total Reward = -5
# Episode 312: Total Reward = -1
# Episode 313: Total Reward = -5
# Episode 314: Total Reward = 1
# Episode 315: Total Reward = -11
# Episode 316: Total Reward = -1
# Episode 317: Total Reward = -29
# Episode 318: Total Reward = 1
# Episode 319: Total Reward = 3
# Episode 320: Total Reward = -29
# Episode 321: Total Reward = -1
# Episode 322: Total Reward = -1
# Episode 323: Total Reward = 1
# Episode 324: Total Reward = -1
# Episode 325: Total Reward = 3
# Episode 326: Total Reward = 1
# Episode 327: Total Reward = -5
# Episode 328: Total Reward = 1
# Episode 329: Total Reward = 5
# Episode 330: Total Reward = 3
# Episode 331: Total Reward = 1
# Episode 332: Total Reward = 3
# Episode 333: Total Reward = 5
# Episode 334: Total Reward = 3
# Episode 335: Total Reward = -3
# Episode 336: Total Reward = -5
# Episode 337: Total Reward = -1
# Episode 338: Total Reward = 3
# Episode 339: Total Reward = -7
# Episode 340: Total Reward = -3
# Episode 341: Total Reward = -3
# Episode 342: Total Reward = 1
# Episode 343: Total Reward = -7
# Episode 344: Total Reward = 5
# Episode 345: Total Reward = 3
# Episode 346: Total Reward = -19
# Episode 347: Total Reward = 5
# Episode 348: Total Reward = 1
# Episode 349: Total Reward = 1
# Episode 350: Total Reward = -9
# Episode 351: Total Reward = 1
# Episode 352: Total Reward = 5
# Episode 353: Total Reward = 3
# Episode 354: Total Reward = 3
# Episode 355: Total Reward = 1
# Episode 356: Total Reward = 3
# Episode 357: Total Reward = 1
# Episode 358: Total Reward = 1
# Episode 359: Total Reward = 1
# Episode 360: Total Reward = 3
# Episode 361: Total Reward = 3
# Episode 362: Total Reward = 3
# Episode 363: Total Reward = 5
# Episode 364: Total Reward = -1
# Episode 365: Total Reward = 5
# Episode 366: Total Reward = 3
# Episode 367: Total Reward = 3
# Episode 368: Total Reward = -3
# Episode 369: Total Reward = 3
# Episode 370: Total Reward = 5
# Episode 371: Total Reward = 5
# Episode 372: Total Reward = 5
# Episode 373: Total Reward = 5
# Episode 374: Total Reward = 3
# Episode 375: Total Reward = -5
# Episode 376: Total Reward = 3
# Episode 377: Total Reward = 5
# Episode 378: Total Reward = -1
# Episode 379: Total Reward = -3
# Episode 380: Total Reward = 5
# Episode 381: Total Reward = 3
# Episode 382: Total Reward = 3
# Episode 383: Total Reward = 1
# Episode 384: Total Reward = 5
# Episode 385: Total Reward = -5
# Episode 386: Total Reward = 5
# Episode 387: Total Reward = -3
# Episode 388: Total Reward = 1
# Episode 389: Total Reward = 3
# Episode 390: Total Reward = 1
# Episode 391: Total Reward = 3
# Episode 392: Total Reward = 3
# Episode 393: Total Reward = -1
# Episode 394: Total Reward = -1
# Episode 395: Total Reward = 3
# Episode 396: Total Reward = 5
# Episode 397: Total Reward = 1
# Episode 398: Total Reward = -1
# Episode 399: Total Reward = -3
# Episode 400: Total Reward = 1
# Episode 401: Total Reward = 5
# Episode 402: Total Reward = 1
# Episode 403: Total Reward = 3
# Episode 404: Total Reward = 3
# Episode 405: Total Reward = -1
# Episode 406: Total Reward = 5
# Episode 407: Total Reward = 3
# Episode 408: Total Reward = 3
# Episode 409: Total Reward = 3
# Episode 410: Total Reward = 1
# Episode 411: Total Reward = 5
# Episode 412: Total Reward = 3
# Episode 413: Total Reward = 3
# Episode 414: Total Reward = -7
# Episode 415: Total Reward = 1
# Episode 416: Total Reward = -9
# Episode 417: Total Reward = 3
# Episode 418: Total Reward = 1
# Episode 419: Total Reward = 1
# Episode 420: Total Reward = 5
# Episode 421: Total Reward = -37
# Episode 422: Total Reward = 3
# Episode 423: Total Reward = 3
# Episode 424: Total Reward = 3
# Episode 425: Total Reward = -5
# Episode 426: Total Reward = 3
# Episode 427: Total Reward = 1
# Episode 428: Total Reward = -1
# Episode 429: Total Reward = 3
# Episode 430: Total Reward = -1
# Episode 431: Total Reward = 1
# Episode 432: Total Reward = 5
# Episode 433: Total Reward = 3
# Episode 434: Total Reward = 5
# Episode 435: Total Reward = -3
# Episode 436: Total Reward = -5
# Episode 437: Total Reward = 5
# Episode 438: Total Reward = 3
# Episode 439: Total Reward = 3
# Episode 440: Total Reward = -7
# Episode 441: Total Reward = -3
# Episode 442: Total Reward = -3
# Episode 443: Total Reward = 1
# Episode 444: Total Reward = 1
# Episode 445: Total Reward = 5
# Episode 446: Total Reward = 5
# Episode 447: Total Reward = 5
# Episode 448: Total Reward = 5
# Episode 449: Total Reward = 1
# Episode 450: Total Reward = 5
# Episode 451: Total Reward = 3
# Episode 452: Total Reward = 3
# Episode 453: Total Reward = 5
# Episode 454: Total Reward = 1
# Episode 455: Total Reward = 3
# Episode 456: Total Reward = -3
# Episode 457: Total Reward = 1
# Episode 458: Total Reward = 3
# Episode 459: Total Reward = -5
# Episode 460: Total Reward = 3
# Episode 461: Total Reward = 5
# Episode 462: Total Reward = 1
# Episode 463: Total Reward = 5
# Episode 464: Total Reward = 5
# Episode 465: Total Reward = 5
# Episode 466: Total Reward = 1
# Episode 467: Total Reward = 3
# Episode 468: Total Reward = 5
# Episode 469: Total Reward = 5
# Episode 470: Total Reward = 5
# Episode 471: Total Reward = 3
# Episode 472: Total Reward = -3
# Episode 473: Total Reward = -5
# Episode 474: Total Reward = 1
# Episode 475: Total Reward = 3
# Episode 476: Total Reward = -1
# Episode 477: Total Reward = 3
# Episode 478: Total Reward = -1
# Episode 479: Total Reward = 1
# Episode 480: Total Reward = 3
# Episode 481: Total Reward = -1
# Episode 482: Total Reward = 5
# Episode 483: Total Reward = 1
# Episode 484: Total Reward = 3
# Episode 485: Total Reward = 3
# Episode 486: Total Reward = 5
# Episode 487: Total Reward = 3
# Episode 488: Total Reward = 3
# Episode 489: Total Reward = 5
# Episode 490: Total Reward = 5
# Episode 491: Total Reward = 3
# Episode 492: Total Reward = 5
# Episode 493: Total Reward = 3
# Episode 494: Total Reward = 3
# Episode 495: Total Reward = 3
# Episode 496: Total Reward = 5
# Episode 497: Total Reward = 5
# Episode 498: Total Reward = 1
# Episode 499: Total Reward = 3
# Episode 500: Total Reward = 1

# %%
# Training loop
env = FLModel()
agent = DQNAgent()
start_state = np.array((0, 0))

n_episodes = 500
for episode in range(n_episodes):
    state = start_state
    done = False
    total_reward = 0

    while not done:
        action = agent.act(state)
        action_name = ["up", "down", "left", "right"][action]
        exog = env.exog_info(state, action_name)
        next_state = env.transition_function(state, action_name, exog)
        reward = env.get_reward(next_state)
        done = env.is_complete(next_state)
        
        agent.remember(state, action, reward, next_state, done)
        state = next_state
        total_reward += reward

        if done:
            print(f"Episode {episode + 1}: Total Reward = {total_reward}")
            break

    agent.replay()
    if episode % agent.update_target_every == 0:
        agent.update_target_network()

# %%
env.run_trained_agent(start_state, agent)
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks9bbdbd40-467b-4559-9e4f-48345256f820 td {border: 1px solid white;}</style><table id="blocks9bbdbd40-467b-4559-9e4f-48345256f820" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (255, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(255, 255, 255);"></td><td title="Index: [0, 1]&#10;Color: (255, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(255, 255, 255);"></td><td title="Index: [0, 2]&#10;Color: (255, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(255, 255, 255);"></td><td title="Index: [0, 3]&#10;Color: (255, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(255, 255, 255);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (255, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(255, 255, 255);"></td><td title="Index: [1, 1]&#10;Color: (255, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(255, 255, 255);"></td><td title="Index: [1, 2]&#10;Color: (255, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(255, 255, 255);"></td><td title="Index: [1, 3]&#10;Color: (255, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(255, 255, 255);"></td></tr><tr><td title="Index: [2, 0]&#10;Color: (255, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(255, 255, 255);"></td><td title="Index: [2, 1]&#10;Color: (255, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(255, 255, 255);"></td><td title="Index: [2, 2]&#10;Color: (255, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(255, 255, 255);"></td><td title="Index: [2, 3]&#10;Color: (255, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(255, 255, 255);"></td></tr><tr><td title="Index: [3, 0]&#10;Color: (255, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(255, 255, 255);"></td><td title="Index: [3, 1]&#10;Color: (255, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(255, 255, 255);"></td><td title="Index: [3, 2]&#10;Color: (255, 255, 255)" style="width: 20px; height: 20px;background-color: rgb(255, 255, 255);"></td><td title="Index: [3, 3]&#10;Color: (0, 0, 255)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 255);"></td></tr></tbody></table>
# Goal reached in 6 steps!
